# %% [markdown]
# # Read a wave2d netCDF output

# %% [markdown]
# ### First, import the script

# %%
import netCDF_Reader as nrd

# %% [markdown]
# ### Now, build your Wave object with the filename

# %%
filename = 'history.nc'
wave = nrd.import_Wave(filename)

# %% [markdown]
# #### What is a Wave object ?

# %%
wave?

# %% [markdown]
# #### Now, we want to know the names of variables that we can plot

# %%
wave.variable_list()
# Out:
# Data variables:
#     p        (time, y, x) float64 ...

# %% [markdown]
# We can choose our variable

# %%
variable = 'p'

# %% [markdown]
# ### Now, we want to build the animation

# %% [markdown]
# How works the method animate?

# %%
wave.animate?

# %% [markdown]
# So, we just have to use the method with the variable that we choose

# %%
wave.animate(variable, save=True)
# Out:
# MovieWriter PillowWriter unavailable; trying to use <class 'matplotlib.animation.PillowWriter'> instead.
# ...........Done!
